# %% [markdown]
# # Gráficos FEVD

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %% [markdown]
# ## TV BVAR(4) findex - 4000 draws

# %%
# Preparación de columnas y datos
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/FEVD/FEVD data findex.xlsx")

# %%
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(15))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(15)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 15, 2))
    ax.set_title(f'{var.split()[0]}', fontsize=12, color='#222222')

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## TV BVAR(4) dimensiones - 4000 draws

# %%
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/FEVD/FEVD data.xlsx")  # cambia por la ruta real

# %%
# Preparación de columnas y datos
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(15))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(15)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 15, 2))
    ax.set_title(f'{var.split()[0]}', fontsize=12, color='#222222')

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## TV BVAR(1) findex - 8000 draws

# %%
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/Gráficos de Tesis/FEVD/FEVD findex 8k.xlsx")

# Preparación de columnas y datos
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(20))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(20)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 20, 5))
    ax.set_title(f'{var.split()[0]}', fontsize=12, color='#222222')

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## TV BVAR(1) dimensiones - 8000 draws

# %%
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/Gráficos de Tesis/FEVD/FEVD dim 8k.xlsx")

# Preparación de columnas y datos
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(20))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(20)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 20, 2))
    ax.set_title(f'{var.split()[0]}', fontsize=12, color='#222222')

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## TV BVAR(2) findex - 8000 draws

# %%
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/Gráficos de Tesis/FEVD/FEVD findex 2lag 8k.xlsx")

# Preparación de columnas y datos
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(20))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(20)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 20, 2))
    ax.set_title(f'{var.split()[0]}', fontsize=12, color='#222222')

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## TV BVAR(2) dimensiones - 8000 draws

# %%
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/Gráficos de Tesis/FEVD/FEVD dim 2lag 8k.xlsx")

# Preparación de columnas y datos
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(20))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(20)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 20, 2))
    ax.set_title(f'{var.split()[0]}', fontsize=12, color='#222222')

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## TV BVAR(4) findex - 8000 draws

# %%
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/Gráficos de Tesis/FEVD/FEVD findex 4lag 8k.xlsx")

# Preparación de columnas y datos
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(20))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(20)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 20, 2))
    ax.set_title(f'{var.split()[0]}', fontsize=12, color='#222222')

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## TV BVAR(4) dimensiones - 8000 draws

# %%
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/Gráficos de Tesis/FEVD/FEVD dim 4lag 8k.xlsx")

# Preparación de columnas y datos
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(20))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(20)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 20, 5))
    ax.set_title(f'{var.split()[0]}', fontsize=12, color='#222222')

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## TV BVAR(4) findex 10k

# %%
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/Gráficos de Tesis/FEVD/FEVD findex 10k.xlsx")

# Preparación de columnas y datos
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(20))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 7))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(20)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 20, 2))
    titulos = [
    'Estabilidad Bancaria',
    'Concentración Bancaria',
    'Inflación',
    'Consumo',
    'Inversión',
    'Producto'
    ]
    ax.set_title(titulos[idx], fontweight='bold', fontsize=14, color='#222222', pad=5)

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()

# %% [markdown]
# ## TV BVAR(4) dim 10k

# %%
df = pd.read_excel("C:/Users/gabri/OneDrive/Desktop/Cato/Tesis/Tesis-paper/Data y gráficos/Gráficos de Tesis/FEVD/FEVD dim 10k.xlsx")

# Preparación de columnas y datos
df.columns = ['Variable_FEVD', 'Variable_Explicativa'] + list(range(20))
variables_objetivo = df['Variable_FEVD'].unique()
colores = sns.color_palette("Set2", n_colors=8) + [(1.0, 0.6, 0.6)]  # 9 colores

# Estilo general
sns.set(style="white", context="notebook", font_scale=1.1)

# Crear subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 8))
axes = axes.flatten()

for idx, var in enumerate(variables_objetivo):
    ax = axes[idx]
    
    sub_df = df[df['Variable_FEVD'] == var]
    datos = sub_df.iloc[:, 2:].values
    explicativas = sub_df['Variable_Explicativa'].values
    horizontes = np.arange(20)

    datos_df = pd.DataFrame(datos.T, columns=explicativas)
    datos_normalizados = datos_df.div(datos_df.sum(axis=1), axis=0)

    # Acumulado para hacer fill_between
    base = np.zeros(len(horizontes))
    for i, col in enumerate(explicativas):
        top = base + datos_normalizados[col].values
        ax.fill_between(
            horizontes, base, top,
            color=colores[i],
            linewidth=0.1,  # línea divisora muy delgada
            edgecolor='black'
        )
        base = top

    ax.set_xlim(0, 14)
    ax.set_ylim(0, 1)
    ax.set_xticks(range(0, 20, 5))
    titulos = [
    'Estabilidad Bancaria',
    'Concentración Bancaria',
    'Inflación',
    'Consumo',
    'Inversión',
    'Producto'
    ]
    ax.set_title(titulos[idx], fontweight='bold', fontsize=14, color='#222222', pad=5)

    # Quitar bordes del gráfico
    for spine in ax.spines.values():
        spine.set_visible(False)

# Leyenda general
handles = [plt.Rectangle((0,0),1,1, color=colores[i], ec='black', linewidth=0.3) for i in range(len(explicativas))]
fig.legend(
    handles, explicativas,
    loc='lower center',
    ncol=9,
    frameon=False,
    fontsize=12,
    handletextpad=0.5,   # reduce espacio entre color y texto
    columnspacing=0.7    # reduce espacio entre columnas
)

# Ajuste de espaciado
plt.subplots_adjust(hspace=0.3)
plt.show()
